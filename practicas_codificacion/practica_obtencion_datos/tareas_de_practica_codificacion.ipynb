# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/math_I/blob/main/practicas_codificacion/practica_obtencion_datos/.ipynb_checkpoints/tareas_de_practica_codificacion-checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# # Ejemplo ilistrativo de obtención de datos y creación de DataFrame y visualización del mismo

# %%
import pandas as alejandra

# %%
url = 'https://raw.githubusercontent.com/marco-canas/math_I/main/A2022M11/DatosEstacion2022-11-16.csv'
alejandra.read_csv(url)
# Out:
#           Tiempo Sistema Bar Trend  Next Record  Barometer  \
# 0    2022-11-16 17:52:56         O          650      29763
# 1    2022-11-16 17:53:01         O          650      29763
# 2    2022-11-16 17:54:00         O          650      29764
# 3    2022-11-16 17:55:00         O          650      29765
# 4    2022-11-16 17:56:00         O          650      29764
# ..                   ...       ...          ...        ...
# 363  2022-11-16 23:55:00         O          662      29822
# 364  2022-11-16 23:56:00         O          662      29820
# 365  2022-11-16 23:57:00         O          662      29819
# 366  2022-11-16 23:58:00         O          662      29820
# 367  2022-11-16 23:59:01         O          662      29820
#
#      Inside Temperature  Inside Humidity  Outside Temperature  Wind Speed  \
# 0                   881               73                  839           1
# 1                   881               73                  839           1
# ...

# %%
url = 'https://raw.githubusercontent.com/marco-canas/math_I/main/A2022M11/DatosEstacion2022-11-17.csv'
alejandra.read_csv(url)
# Out:
#            Tiempo Sistema Bar Trend  Next Record  Barometer  \
# 0     2022-11-17 00:00:00         O          662      29819
# 1     2022-11-17 00:01:00         O          663      29818
# 2     2022-11-17 00:02:00         O          663      29822
# 3     2022-11-17 00:03:00         O          663      29820
# 4     2022-11-17 00:04:01         O          663      29821
# ...                   ...       ...          ...        ...
# 1432  2022-11-17 23:55:00         O          707      29828
# 1433  2022-11-17 23:56:06         O          707      29830
# 1434  2022-11-17 23:57:00         O          707      29830
# 1435  2022-11-17 23:58:00         O          707      29830
# 1436  2022-11-17 23:59:01         O          707      29829
#
#       Inside Temperature  Inside Humidity  Outside Temperature  Wind Speed  \
# 0                    849               77                  770           0
# 1                    849               77                  770           1
# ...

# %% [markdown]
# # Algoritmo para obtener los datos
#
#
# 1. Obtenga la url en raw
# 2. crea una variable de python (estructura < nombre variable> = <"dirección url">)
# 3. utilizar pd.read_csv()

# %% [markdown]
# # Tareas de memorización

# %% [markdown]
# ## Vocabulary

# %% [markdown]
# 1. read = leer
# 2. desktop = escritorio
# 3. small
# 4. Medium
# 5. Large
# 6. ExtraLarge
# 7. set: conjunto
# 8. add: adicionar
# 9. below: abajo
# 10. above: arriba
# 11. as: como
# 12. raw: crudo
# 13. barometer:
# 14. inside: adentro
# 15. wind: viento

# %% [markdown]
# # Nombres de las funciones que convierten en DataFrame

# %% [markdown]
# * pd.read_csv()
#
# * pd.read_excel()

# %% [markdown]
# # Estructuras de datos de python

# %% [markdown]
# 1. Listas
# 2. Tuplas
# 3. Diccionarios
# 4. array de NumPy
# 5. DataFrame
